# %%
from IPython.display import clear_output
from pipeline.predict import make_predictions
from pipeline.config import get_config

config = get_config()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from IPython.display import clear_output
# ----> 2 from pipeline.predict import make_predictions
#       3 from pipeline.config import get_config
#       5 config = get_config()
#
# File ~/projects/jupyterlab/Notebooks/tft_dev/pipeline/predict.py:9
#       7 from pytorch_forecasting import TemporalFusionTransformer, TimeSeriesDataSet
#       8 from pipeline.config import get_config
# ----> 9 from feature_creation import fc, feature_creation_every_row
#      10 from model import build_time_series_ds
#      11 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'feature_creation'

# %%
(
    (raw_preds, df_true),  # access different quantiles with raw_preds[index of fuel type][:,quantile(0-6)] 
    (mae, sum_mae, adj_r2),
    f1,
    f2,
) = make_predictions(config, "2024-01-01 00:00:00", "checkpoints/6/epoch=9-val_loss=670.25.ckpt", 3)


clear_output(wait=False)
print(f"MAE: {mae:.2f}")
print(f"Sum MAE: {sum_mae:.2f}")
print(f"Adj-R2: {adj_r2:.2f}")
# Out:
# MAE: 1585.50
# Sum MAE: 7662.14
# Adj-R2: 0.98

# %%
raw_preds.shape
# Out:
# (8, 168, 7)

# %%
f1

# %%
f2
